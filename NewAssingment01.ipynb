# %% [markdown]
# ## Assingment No.1

# %%
#Q1.Prime Number-
num = int(input("Enter a number: "))

if num <= 1:
    print(num, "is not a prime number")
else:
    is_prime = True
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            break

    if is_prime:
        print(num, "is a prime number")
    else:
        print(num, "is not a prime number")
# Out:
# Enter a number:  25
# 25 is not a prime number

# %%
#Q2.Random Numbers-
import random
num1 = random.randint(1, 10)
num2 = random.randint(1, 10)

print("What is the product of", num1, "and", num2, "?")
answer = int(input("Enter your answer: "))

if answer == num1 * num2:
    print("Correct answer!")
else:
    print("Wrong answer. The correct answer is", num1 * num2)
# Out:
# What is the product of 10 and 7 ?
# Enter your answer:  69
# Wrong answer. The correct answer is 70

# %%
#Q3.Squares of EVEN numbers from 100 to 200

for i in range(100, 201):
    if i % 2 == 0:
        print("Square of", i, "is", i * i)
# Out:
# Square of 100 is 10000
# Square of 102 is 10404
# Square of 104 is 10816
# Square of 106 is 11236
# Square of 108 is 11664
# Square of 110 is 12100
# Square of 112 is 12544
# Square of 114 is 12996
# Square of 116 is 13456
# Square of 118 is 13924
# Square of 120 is 14400
# Square of 122 is 14884
# Square of 124 is 15376
# Square of 126 is 15876
# Square of 128 is 16384
# Square of 130 is 16900
# Square of 132 is 17424
# Square of 134 is 17956
# Square of 136 is 18496
# Square of 138 is 19044
# Square of 140 is 19600
# Square of 142 is 20164
# Square of 144 is 20736
# Square of 146 is 21316
# Square of 148 is 21904
# Square of 150 is 22500
# Square of 152 is 23104
# Square of 154 is 23716
# Square of 156 is 24336
# Square of 158 is 24964
# Square of 160 is 25600
# Square of 162 is 26244
# Square of 164 is 26896
# Square of 166 is 27556
# Square of 168 is 28224
# Square of 170 is 28900
# Square of 172 is 29584
# Square of 174 is 30276
# Square of 176 is 30976
# Square of 178 is 31684
# ...

# %%
#Q4.Hospital Bill-
print("HOSPITAL BILLING SYSTEM")
print()

days_stayed = 4
num_lab_tests = 3
medicine_charges = 2400

room_charges = days_stayed * 2000
doctor_fee = 1500
lab_charges = num_lab_tests * 300

total_bill = room_charges + doctor_fee + lab_charges + medicine_charges

if total_bill > 10000:
    discount = total_bill * 0.10
    final_bill = total_bill - discount
    print("Discount of 10% applied!")
else:
    discount = 0
    final_bill = total_bill

print()
print("        Bill Details          ")
print("Room charges (4 days)  : Rs.", room_charges)
print("Doctor consultation fee: Rs.", doctor_fee)
print("Lab test charges       : Rs.", lab_charges)
print("Medicine charges       : Rs.", medicine_charges)
print("------------------------------")
print("Total before discount  : Rs.", total_bill)
print("Discount applied       : Rs.", discount)
print("FINAL BILL             : Rs.", final_bill)
# Out:
# HOSPITAL BILLING SYSTEM
#
# Discount of 10% applied!
#
#         Bill Details
# Room charges (4 days)  : Rs. 8000
# Doctor consultation fee: Rs. 1500
# Lab test charges       : Rs. 900
# Medicine charges       : Rs. 2400
# ------------------------------
# Total before discount  : Rs. 12800
# Discount applied       : Rs. 1280.0
# FINAL BILL             : Rs. 11520.0
