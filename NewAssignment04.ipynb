# %% [markdown]
# ## Assignment No.4

# %%
#Task1
import pandas as pd
patient_df = pd.read_csv("Patient_Data.csv")
billing_df = pd.read_csv("Billing_Data.csv")
patient_df.info()
patient_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       6 non-null      int64
#  1   Name            6 non-null      object
#  2   Department      6 non-null      object
#  3   Doctor          6 non-null      object
#  4   BillAmount      4 non-null      float64
#  5   ReceptionistID  6 non-null      int64
#  6   CheckInTime     6 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 468.0+ bytes
#         PatientID   BillAmount  ReceptionistID
# count    6.000000     4.000000        6.000000
# mean   102.666667  5925.000000        1.666667
# std      1.632993  1192.686044        0.816497
# min    101.000000  5000.000000        1.000000
# 25%    101.250000  5000.000000        1.000000
# 50%    102.500000  5600.000000        1.500000
# 75%    103.750000  6525.000000        2.000000
# ...

# %%
#Task2
relevant_cols = ['PatientID', 'Department', 'Doctor', 'BillAmount']
billing_relevant_df = patient_df[relevant_cols]
print(billing_relevant_df)
# Out:
#    PatientID   Department     Doctor  BillAmount
# 0        101   Cardiology  Dr. Smith      5000.0
# 1        102    Neurology   Dr. John         NaN
# 2        103  Orthopedics    Dr. Lee      7500.0
# 3        104   Cardiology  Dr. Smith      6200.0
# 4        105  Dermatology   Dr. Rose         NaN
# 5        101   Cardiology  Dr. Smith      5000.0

# %%
#Task3
patient_df = patient_df.drop(columns=['ReceptionistID', 'CheckInTime'])
print(patient_df)
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %%
#Task4
dept_bill = patient_df.groupby('Department')['BillAmount'].sum().reset_index()
print(dept_bill)
# Out:
#     Department  BillAmount
# 0   Cardiology     16200.0
# 1  Dermatology         0.0
# 2    Neurology         0.0
# 3  Orthopedics      7500.0

# %%
#Task5
patient_df = patient_df.drop_duplicates(subset='PatientID', keep='first')
print(patient_df)
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN

# %%
#Task6
mean_bill = patient_df['BillAmount'].mean()
patient_df['BillAmount'] = patient_df['BillAmount'].fillna(mean_bill)
print(patient_df)
print(mean_bill)
# Out:
#    PatientID     Name   Department     Doctor   BillAmount
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000
# 1        102      Bob    Neurology   Dr. John  6233.333333
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000
# 3        104    David   Cardiology  Dr. Smith  6200.000000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333
# 6233.333333333333

# %%
#Task7
merged_df = pd.merge(patient_df, billing_df, on='PatientID', how='left')
print(merged_df)
# Out:
#    PatientID     Name   Department     Doctor   BillAmount  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000              2000
# 1        102      Bob    Neurology   Dr. John  6233.333333              1500
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000              2500
# 3        104    David   Cardiology  Dr. Smith  6200.000000              3000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333              1000
#
#    FinalAmount
# 0         3000
# 1         3500
# 2         5000
# 3         3200
# 4         4000

# %%
#Task8
new_patients = pd.DataFrame({...})
merged_df = pd.concat([merged_df, new_patients], ignore_index=True)
print(merged_df)
# Out:
#    PatientID     Name   Department     Doctor   BillAmount  InsuranceCovered  \
# 0      101.0    Alice   Cardiology  Dr. Smith  5000.000000            2000.0
# 1      102.0      Bob    Neurology   Dr. John  6233.333333            1500.0
# 2      103.0  Charlie  Orthopedics    Dr. Lee  7500.000000            2500.0
# 3      104.0    David   Cardiology  Dr. Smith  6200.000000            3000.0
# 4      105.0      Eva  Dermatology   Dr. Rose  6233.333333            1000.0
# 5        NaN      NaN          NaN        NaN          NaN               NaN
#
#    FinalAmount         0
# 0       3000.0       NaN
# 1       3500.0       NaN
# 2       5000.0       NaN
# 3       3200.0       NaN
# 4       4000.0       NaN
# 5          NaN  Ellipsis

# %%
#Task9
extra_cols = pd.DataFrame({'InsuranceCovered': [...], 'FinalAmount': [...]})
merged_df = pd.concat([merged_df, extra_cols], axis=1)
print(merged_df.columns.tolist())
# Out:
# ['PatientID', 'Name', 'Department', 'Doctor', 'BillAmount', 'InsuranceCovered', 'FinalAmount', 0, 'InsuranceCovered', 'FinalAmount']
